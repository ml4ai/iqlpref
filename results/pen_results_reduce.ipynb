# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from prettytable import PrettyTable

pd.options.mode.copy_on_write = True

# %%
mr_cloned_df = pd.concat(
    [
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_0.csv"
        ),
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_10.csv"
        ),
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_20.csv"
        ),
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_30.csv"
        ),
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_40.csv"
        ),
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_50.csv"
        ),
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_60.csv"
        ),
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_70.csv"
        ),
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_80.csv"
        ),
        pd.read_csv(
            "../cloned_pen_models_pref/iql-p-D4RL/pen/pen_cloned_eval_pref_median_reduce_90.csv"
        ),
    ]
)
mr_cloned_df = mr_cloned_df.reset_index()

median_mr_cloned_idx = (
    mr_cloned_df.groupby("model_id")["median_score"].transform("max")
    == mr_cloned_df["median_score"]
)
best_median_mr_cloned_df = mr_cloned_df[median_mr_cloned_idx]

# %%
best_median_mr_cloned_df
# Out:
#       index             dataset   model_id  checkpoint_id  median_score  \
# 30       30  D4RL/pen/cloned-v2   reduce_0         154999   2845.539829
# 359     159  D4RL/pen/cloned-v2  reduce_10         799999   2635.274369
# 438      38  D4RL/pen/cloned-v2  reduce_20         194999   3084.302474
# 688      88  D4RL/pen/cloned-v2  reduce_30         444999   2978.969844
# 939     139  D4RL/pen/cloned-v2  reduce_40         699999   3204.007982
# 1001      1  D4RL/pen/cloned-v2  reduce_50           9999   4255.548215
# 1227     27  D4RL/pen/cloned-v2  reduce_60         139999   2857.582155
# 1419     19  D4RL/pen/cloned-v2  reduce_70          99999   2714.258532
# 1624     24  D4RL/pen/cloned-v2  reduce_80         124999   3323.101794
# 1822     22  D4RL/pen/cloned-v2  reduce_90         114999   2854.787263
#
#       num_episodes
# 30            5000
# 359           5000
# 438           5000
# 688           5000
# 939           5000
# 1001          5000
# 1227          5000
# ...

# %%
mr_expert_df = pd.concat(
    [
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_0.csv"
        ),
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_10.csv"
        ),
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_20.csv"
        ),
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_30.csv"
        ),
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_40.csv"
        ),
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_50.csv"
        ),
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_60.csv"
        ),
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_70.csv"
        ),
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_80.csv"
        ),
        pd.read_csv(
            "../expert_pen_models_pref/iql-p-D4RL/pen/pen_expert_eval_pref_median_reduce_90.csv"
        ),
    ]
)
mr_expert_df = mr_expert_df.reset_index()

median_mr_expert_idx = (
    mr_expert_df.groupby("model_id")["median_score"].transform("max")
    == mr_expert_df["median_score"]
)
best_median_mr_expert_df = mr_expert_df[median_mr_expert_idx]

# %%
best_median_mr_expert_df
# Out:
#       index             dataset   model_id  checkpoint_id  median_score  \
# 45       45  D4RL/pen/expert-v2   reduce_0         229999  10044.560640
# 266      66  D4RL/pen/expert-v2  reduce_10         334999  10166.527630
# 422      22  D4RL/pen/expert-v2  reduce_20         114999  10017.024162
# 655      55  D4RL/pen/expert-v2  reduce_30         279999  10040.814442
# 850      50  D4RL/pen/expert-v2  reduce_40         254999  10323.766354
# 1045     45  D4RL/pen/expert-v2  reduce_50         229999  10320.595938
# 1227     27  D4RL/pen/expert-v2  reduce_60         139999  10042.735930
# 1435     35  D4RL/pen/expert-v2  reduce_70         179999  10163.074590
# 1612     12  D4RL/pen/expert-v2  reduce_80          64999   9969.146417
# 1812     12  D4RL/pen/expert-v2  reduce_90          64999   9912.279727
#
#       num_episodes
# 45            5000
# 266           5000
# 422           5000
# 655           5000
# 850           5000
# 1045          5000
# 1227          5000
# ...

# %%
# pt_cloned_df = pd.concat(
#     [
#         pd.read_csv(
#             "../cloned_pen_models_pt/iql-pt-D4RL/pen/pen_cloned_eval_pt_median_reduce_0.csv"
#         ),
#         pd.read_csv(
#             "../cloned_pen_models_pt/iql-pt-D4RL/pen/pen_cloned_eval_pt_median_reduce_10.csv"
#         ),
#         pd.read_csv(
#             "../cloned_pen_models_pt/iql-pt-D4RL/pen/pen_cloned_eval_pt_median_reduce_20.csv"
#         ),
#         pd.read_csv(
#             "../cloned_pen_models_pt/iql-pt-D4RL/pen/pen_cloned_eval_pt_median_reduce_30.csv"
#         ),
#     ]
# )
# pt_cloned_df = pt_cloned_df.reset_index()

# median_pt_cloned_idx = (
#     pt_cloned_df.groupby("model_id")["median_score"].transform("max")
#     == pt_cloned_df["median_score"]
# )
# best_median_pt_cloned_df = pt_cloned_df[median_pt_cloned_idx]

# %%
# best_median_pt_cloned_df
